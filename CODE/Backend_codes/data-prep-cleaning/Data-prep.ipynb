# %%
import pandas
import sklearn
import numpy as np

# %%
# !ls -lah /data
# Out:
# total 1.3G
# drwxrwxrwx. 2    1022 svcmltech 4.0K Nov  5 15:38 .
# drwxr-xr-x. 1 root    root      4.0K Nov 15 13:17 ..
# -rw-rw-r--. 1 jupyter svcmltech  82K Nov  5 15:34 bridged_indicator.csv
# -rw-rw-r--. 1    1022 svcmltech 548M Nov  5 07:53 Indicators.csv
# -rw-rw-r--. 1 jupyter svcmltech 250M Nov  5 15:33 joined_cleaned_data.csv
# -rw-rw-r--. 1 jupyter svcmltech 255M Nov  5 15:39 joined_raw_transaction_data.csv
# -rw-rw-r--. 1    1022 svcmltech  92M Nov  5 07:53 RawTransactDataFull_3110.csv
# -rw-rw-r--. 1    1022 svcmltech  90M Nov  5 07:53 TransactDataClean_3110.csv

# %%
clean_data=pandas.read_csv('/data/RawTransactDataFull_3110.csv')

# %%
clean_data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
clean_data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
clean_data.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# dtype: object

# %%
clean_data.astype({'Country':'str'}).dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# dtype: object

# %%
clean_data.Country.astype(str)
# Out:
# 0          United Kingdom
# 1          United Kingdom
# 2          United Kingdom
# 3          United Kingdom
# 4          United Kingdom
#                 ...
# 1067366            France
# 1067367            France
# 1067368            France
# 1067369            France
# 1067370            France
# Name: Country, Length: 1067371, dtype: object

# %%
unique_countries=list(clean_data.Country.unique())

# %%
indicator_data=pandas.read_csv('/data/Indicators.csv')

# %%
indicator_data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', 'Year',
#        'Value'],
#       dtype='object')

# %%
indicator_data.Year.unique()
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015])

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
clean_data['InvoiceDate'].astype('datetime64[ns]')
# Out:
# 0         2009-12-01 07:45:00
# 1         2009-12-01 07:45:00
# 2         2009-12-01 07:45:00
# 3         2009-12-01 07:45:00
# 4         2009-12-01 07:45:00
#                   ...
# 1067366   2011-12-09 12:50:00
# 1067367   2011-12-09 12:50:00
# 1067368   2011-12-09 12:50:00
# 1067369   2011-12-09 12:50:00
# 1067370   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 1067371, dtype: datetime64[ns]

# %%
Year=clean_data['InvoiceDate'].astype('datetime64[ns]').dt.year
clean_data['Year'] = clean_data['InvoiceDate'].astype('datetime64[ns]').dt.year

# %%
data_years= list(years.unique())
data_years
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2231/2197516198.py in <module>
# ----> 1 data_years= list(years.unique())
#       2 data_years
#
# NameError: name 'years' is not defined

# %%
indicator_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5656458 entries, 0 to 5656457
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   CountryName    object
#  1   CountryCode    object
#  2   IndicatorName  object
#  3   IndicatorCode  object
#  4   Year           int64
#  5   Value          float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 258.9+ MB

# %%
sub_indictator_data=indicator_data[indicator_data.Year.isin(data_years)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2231/2988608956.py in <module>
# ----> 1 sub_indictator_data=indicator_data[indicator_data.Year.isin(data_years)]
#
# NameError: name 'data_years' is not defined

# %%
sub_indicator_countries=sub_indictator_data.CountryName.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2231/2151059093.py in <module>
# ----> 1 sub_indicator_countries=sub_indictator_data.CountryName.unique()
#
# NameError: name 'sub_indictator_data' is not defined

# %%
unique_countries=set(unique_countries)

# %%
sub_indicator_countries=set(sub_indicator_countries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2231/223483447.py in <module>
# ----> 1 sub_indicator_countries=set(sub_indicator_countries)
#
# NameError: name 'sub_indicator_countries' is not defined

# %%
unique_countries
# Out:
# {'Australia',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Bermuda',
#  'Brazil',
#  'Canada',
#  'Channel Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'EIRE',
#  'European Community',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Lebanon',
#  'Lithuania',
#  'Malta',
#  'Netherlands',
#  'Nigeria',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'RSA',
#  'Saudi Arabia',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Thailand',
#  'USA',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Unspecified',
#  'West Indies'}

# %%
sub_indicator_countries
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
# ...

# %%
unique_countries- sub_indicator_countries
# Out:
# {'EIRE',
#  'European Community',
#  'Hong Kong',
#  'Korea',
#  'RSA',
#  'USA',
#  'Unspecified',
#  'West Indies'}

# %%
country_maps={'Ireland':'EIRE','Euro area':'European Community','Hong Kong SAR, China':'Hong Kong','Korea, Rep.':'Korea','South Africa':'RSA','United States':'USA','Caribbean small states': 'West Indies','Other small states':'Unspecified'}

# %%
country_maps.keys()
# Out:
# dict_keys(['Ireland', 'Euro area', 'Hong Kong SAR, China', 'Korea, Rep.', 'South Africa', 'United States', 'Caribbean small states', 'Other small states'])

# %%
country_maps.values()
# Out:
# dict_values(['EIRE', 'European Community', 'Hong Kong', 'Korea', 'RSA', 'USA', 'West Indies', 'Unspecified'])

# %%
# find replace,
#filter keys
indicator_data['CountryName']=indicator_data['CountryName'].replace(country_maps.keys(),country_maps.values())

# %%
unique_countries - set(sub_indictator_data.CountryName.unique())
# Out:
# {'EIRE',
#  'European Community',
#  'Hong Kong',
#  'Korea',
#  'RSA',
#  'USA',
#  'Unspecified',
#  'West Indies'}

# %%
sub_indictator_data.CountryName.unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics',
#        'East Asia & Pacific (all income levels)',
#        'East Asia & Pacific (developing only)', 'Euro area',
#        'Europe & Central Asia (all income levels)',
#        'Europe & Central Asia (developing only)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'High income: nonOECD', 'High income: OECD',
#        'Latin America & Caribbean (all income levels)',
#        'Latin America & Caribbean (developing only)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa (all income levels)',
#        'Middle East & North Africa (developing only)', 'Middle income',
#        'North America', 'OECD members', 'Other small states',
# ...

# %%
sub_indictator_data[sub_indictator_data.CountryName == 'Ireland']
# Out:
#         CountryName CountryCode  \
# 4749741     Ireland         IRL
# 4749742     Ireland         IRL
# 4749743     Ireland         IRL
# 4749744     Ireland         IRL
# 4749745     Ireland         IRL
# ...             ...         ...
# 5114941     Ireland         IRL
# 5114942     Ireland         IRL
# 5114943     Ireland         IRL
# 5114944     Ireland         IRL
# 5114945     Ireland         IRL
#
#                                              IndicatorName  \
# 4749741  Adjusted net enrolment rate, primary, both sex...
# 4749742     Adjusted net national income (annual % growth)
# 4749743   Adjusted net national income (constant 2005 US$)
# 4749744         Adjusted net national income (current US$)
# 4749745  Adjusted net national income per capita (annua...
# ...                                                    ...
# 5114941  Vulnerable employment, total (% of total emplo...
# 5114942  Wage and salaried workers, female (% of female...
# ...

# %%
sub_indictator_data[sub_indictator_data.CountryName.isin(country_maps.keys())].groupby(['CountryName','Year']).size()
# Out:
# CountryName             Year
# Caribbean small states  2009     518
#                         2010     557
#                         2011     493
# Euro area               2009     570
#                         2010     611
#                         2011     568
# Hong Kong SAR, China    2009     679
#                         2010     673
#                         2011     643
# Ireland                 2009     742
#                         2010     796
#                         2011     736
# Korea, Rep.             2009     744
#                         2010     785
#                         2011     693
# Other small states      2009     523
#                         2010     562
#                         2011     518
# South Africa            2009    1009
#                         2010    1061
#                         2011    1022
# United States           2009     717
#                         2010     753
#                         2011     682
# dtype: int64

# %%
e[indicator_data.Year.isin(data_years)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2209/1404605049.py in <module>
# ----> 1 e[indicator_data.Year.isin(data_years)]
#
# /libraries/test-env-ds/lib/python3.8/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# /libraries/test-env-ds/lib/python3.8/site-packages/pandas/core/base.py in __getitem__(self, key)
#     220             if len(self.obj.columns.intersection(key)) != len(key):
#     221                 bad_keys = list(set(key).difference(self.obj.columns))
# --> 222                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     223             return self._gotitem(list(key), ndim=2)
#     224
#
# ...

# %%
for key,val in country_maps.items():
    sub_indictator_data.loc[(sub_indictator_data.CountryName == key),'CountryName']=val
# Out:
# /libraries/test-env-ds/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
unique_countries - set(sub_indictator_data.CountryName.unique())
# Out:
# set()

# %%
sub_indictator_data
# Out:
#         CountryName CountryCode  \
# 4660437  Arab World         ARB
# 4660438  Arab World         ARB
# 4660439  Arab World         ARB
# 4660440  Arab World         ARB
# 4660441  Arab World         ARB
# ...             ...         ...
# 5202279    Zimbabwe         ZWE
# 5202280    Zimbabwe         ZWE
# 5202281    Zimbabwe         ZWE
# 5202282    Zimbabwe         ZWE
# 5202283    Zimbabwe         ZWE
#
#                                              IndicatorName  \
# 4660437  Adjusted net enrolment rate, primary, both sex...
# 4660438   Adjusted net enrolment rate, primary, female (%)
# 4660439     Adjusted net enrolment rate, primary, male (%)
# 4660440         Adjusted net national income (current US$)
# 4660441  Adjusted net national income per capita (curre...
# ...                                                    ...
# 5202279  Women's share of population ages 15+ living wi...
# 5202280  Youth literacy rate, population 15-24 years, b...
# ...

# %%
csub_indictator_data = sub_indictator_data[sub_indictator_data.CountryName.isin(unique_countries)]

# %%
csub_indictator_data
# Out:
#          CountryName CountryCode  \
# 4660958  West Indies         CSS
# 4660959  West Indies         CSS
# 4660960  West Indies         CSS
# 4660961  West Indies         CSS
# 4660962  West Indies         CSS
# ...              ...         ...
# 5195321          USA         USA
# 5195322          USA         USA
# 5195323          USA         USA
# 5195324          USA         USA
# 5195325          USA         USA
#
#                                              IndicatorName      IndicatorCode  \
# 4660958  Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
# 4660959   Adjusted net enrolment rate, primary, female (%)     SE.PRM.TENR.FE
# 4660960     Adjusted net enrolment rate, primary, male (%)     SE.PRM.TENR.MA
# 4660961         Adjusted net national income (current US$)     NY.ADJ.NNTY.CD
# 4660962  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ...                                                    ...                ...
# ...

# %%
list_of_world_features=list()

# %%
r= '''
GDP at market prices (current US$)
GDP per capita (current US$)
Population, total
Household final consumption expenditure, etc. (% of GDP)
Household final consumption expenditure, etc. (current US$)
Inflation, consumer prices (annual %)
Inflation, GDP deflator (annual %)
Gross fixed capital formation (annual % growth)
Real interest rate (%)
'''

# %%
features=r.split('\n')[1:-1]

# %%
csub_indictator_data.head()
# Out:
#          CountryName CountryCode  \
# 4660958  West Indies         CSS
# 4660959  West Indies         CSS
# 4660960  West Indies         CSS
# 4660961  West Indies         CSS
# 4660962  West Indies         CSS
#
#                                              IndicatorName      IndicatorCode  \
# 4660958  Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
# 4660959   Adjusted net enrolment rate, primary, female (%)     SE.PRM.TENR.FE
# 4660960     Adjusted net enrolment rate, primary, male (%)     SE.PRM.TENR.MA
# 4660961         Adjusted net national income (current US$)     NY.ADJ.NNTY.CD
# 4660962  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
#
#          Year         Value
# 4660958  2009  9.214480e+01
# 4660959  2009  9.265307e+01
# 4660960  2009  9.165317e+01
# 4660961  2009  4.084315e+10
# 4660962  2009  5.996457e+03

# %%
final_sub_indicator_data=csub_indictator_data[csub_indictator_data.IndicatorName.isin(features)]

# %%
final_sub_indicator_data
# Out:
#          CountryName CountryCode  \
# 4661109  West Indies         CSS
# 4661112  West Indies         CSS
# 4661170  West Indies         CSS
# 4661171  West Indies         CSS
# 4661194  West Indies         CSS
# ...              ...         ...
# 5194978          USA         USA
# 5195010          USA         USA
# 5195011          USA         USA
# 5195184          USA         USA
# 5195205          USA         USA
#
#                                              IndicatorName      IndicatorCode  \
# 4661109                 GDP at market prices (current US$)     NY.GDP.MKTP.CD
# 4661112                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 4661170  Household final consumption expenditure, etc. ...     NE.CON.PETC.ZS
# 4661171  Household final consumption expenditure, etc. ...     NE.CON.PETC.CD
# 4661194              Inflation, consumer prices (annual %)     FP.CPI.TOTL.ZG
# ...                                                    ...                ...
# ...

# %%
final_indicator_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1065 entries, 4661109 to 5195205
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    1065 non-null   object
#  1   IndicatorName  1065 non-null   object
#  2   Year           1065 non-null   int64
#  3   Value          1065 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 41.6+ KB

# %%
final_indicator_csv[(final_indicator_csv.IndicatorName == features[0]) & (final_indicator_csv.CountryName == "West Indies") & (final_indicator_csv.Year == 2009) ].Value.iloc[0]
# Out:
# 55910552004.0644

# %%
for feature in features:
    clean_data[feature]=np.NaN
    clean_data[feature]=clean_data[feature].astype(float)
    for year in data_years:
        for country in unique_countries:
#             print(feature+" "+str(year)+" "+country)
            val= final_indicator_csv[(final_indicator_csv.IndicatorName == feature) & (final_indicator_csv.CountryName == country) & (final_indicator_csv.Year == year) ].Value
#             print(len(val))
            if len(val) > 0:
                clean_data.loc[( (clean_data.Country == country) & (clean_data.Year == year)),feature] = val.iloc[0]

# %%
clean_data['GDP at market prices (current US$)']=np.NaN
clean_data['GDP at market prices (current US$)']=clean_data['GDP at market prices (current US$)'].astype(float)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045327 entries, 0 to 1045326
# Data columns (total 18 columns):
#  #   Column                                                       Non-Null Count    Dtype
# ---  ------                                                       --------------    -----
#  0   Invoice                                                      1045327 non-null  object
#  1   StockCode                                                    1045327 non-null  object
#  2   Quantity                                                     1045327 non-null  int64
#  3   InvoiceDate                                                  1045327 non-null  object
#  4   Price                                                        1045327 non-null  float64
#  5   Customer ID                                                  812920 non-null   float64
#  6   Country                                                      1045327 non-null  object
# ...

# %%
final_indicator_csv[final_indicator_csv.CountryName == "West Indies"]
# Out:
#          CountryName                                      IndicatorName  Year  \
# 4661109  West Indies                 GDP at market prices (current US$)  2009
# 4661112  West Indies                       GDP per capita (current US$)  2009
# 4661170  West Indies  Household final consumption expenditure, etc. ...  2009
# 4661171  West Indies  Household final consumption expenditure, etc. ...  2009
# 4661194  West Indies              Inflation, consumer prices (annual %)  2009
# 4661195  West Indies                 Inflation, GDP deflator (annual %)  2009
# 4661377  West Indies                                  Population, total  2009
# 4839726  West Indies                 GDP at market prices (current US$)  2010
# 4839729  West Indies                       GDP per capita (current US$)  2010
# 4839787  West Indies  Household final consumption expenditure, etc. ...  2010
# 4839788  West Indies  Household final consumption expenditure, etc. ...  2010
# ...

# %%
clean_data.to_csv('/data/joined_raw_transaction_data.csv')

# %%
final_indicator_csv.to_csv('/data/bridged_indicator.csv')
